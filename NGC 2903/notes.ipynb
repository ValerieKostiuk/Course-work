# %% [markdown]
# # Перечень статей и наблюдательных данных для NGC 2903

# %%
from IPython.display import Image
from IPython.display import IFrame
from wand.image import Image 
# %pylab
# %matplotlib inline
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
Image('./images/characteristics.png')

# %% [markdown]
# http://articles.adsabs.harvard.edu/pdf/1960ApJ...132..640B-
# (THE ROTATION, MASS DISTRIBUTION, AND MASS OF NGC 2903* E. Margaret Burbidge, G. R. Burbidge, and K. H. Prendergast)

# %% [markdown]
# ### rotation curves in position angles 24 and 11 degrees

# %%
Image('./images/Rotation-curve_1.png')

# %%
Image('./images/Rotation-curve_2.png')

# %% [markdown]
# http://articles.adsabs.harvard.edu/pdf/1997A%26A...325...81P

# %% [markdown]
# Circumnuclear HII region in star-forming rings are characterised by an ionised gas mass $10^4-10^5 M_{\odot}$.
# The circumnuclear region of the three galaxies(NGC 2903,NGC 3351 and NGC 3504) is characterised by an average molecular gas surface density $ \Sigma_{H_{2}}= 280 M_{\odot} pc^{−2}$, and average $L_{IR}/M_{H_2}= 21 L_{\odot} M_{\odot}^{−1}$.

# %% [markdown]
# > A more spectacular example of star formation in a hot-spot galaxy is NGC 2903. The large infrared luminosities and radio continuum emission clearly indicate the presence of a nuclear starburst (Wynn-Williams & Becklin 1985).

# %% [markdown]
# ### Circumnuclear molecular gas

# %%
Image('./images/distribution_CO.png')

# %% [markdown]
# >The CO J=2→1 spectra obtained toward the central region of
# this galaxy show an elongated molecular gas distribution along
# the North-South direction.
#
# >The starburst giving rise to the infrared and radio continuum
# emission seems to take place over the whole area where CO
# emission has been detected.
#
# >We obtain $ L_{FIR}/M_{H_2}$ ∼ 21 $ L_{\odot} M_{\odot}^{−1}$ for the inner 30" × 36" , and
# $L_{FIR}/M_{H_2}$ > $16  L_{\odot} M_{\odot}^{−1}$ for the inner 8".

# %% [markdown]
# FORMULA

# %% [markdown]
# ### Circumnuclear ionized gas

# %%
Image('./images/table_circumnuclear_HII.png')

# %%
Image('./images/picture_circumnuclear_HII.png')

# %% [markdown]
# > Although the overall ionized gas distribution agrees well
# with the radio continuum emission (Wynn-Williams & Becklin
# 1985), the location of the prominent HII regions do not exactly
# correspond with the radio continuum emission peaks observed
# at 2 cm and 20 cm. The lack of spatial coincidence between the radio continuum and Hα peaks can be understood if the HII regions indicated by the warm Hα emitting gas do not trace the overall
# star-formation.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# The starburst has three phases:
# - 1) The accretion phase when the gas accretes to the center of the galaxy, or in a ring around the inner Lindblad resonance;
# - 2)The turn-on phase when the density reaches a high critical value;
# - 3) The starburst phase when the star formation proceeds in a high density environment at a extremely high rate.
# ( Как я поняла, NGC 2903  находится на последней стадии)

# %% [markdown]
# Under the GIM, the duration of the star formation ($ \tau_{SF} $) and the star formation rate (SFR) depend
# on the gas density with $\tau_{SF} \propto \rho^{−0.5}$ and $SFR \propto \rho^{1.5}$ , respectively (Elmegreen 1994).

# %% [markdown]
# http://articles.adsabs.harvard.edu/pdf/2007MNRAS.382..251D

# %% [markdown]
# ### The spatial distribution of the $H\alpha$ flux along the slit

# %%
Image('./images/Halpha_map.png')

# %%
Image('./images/Halpha_table.png')

# %%
Image('./images/Halpha_profiles.png')

# %%
Image('./images/properties.png')

# %% [markdown]
# - L(H$\alpha$)-number of Luman $\alpha$ photons
# - Q($H^0$)- nuber of Hydrogen ionizing photons
# - u- ionization parameter
# - M*- mass of ionizing stars
# > According to these models, a relation exists between the degree of evolution of the cluster, as
# represented by its Hβ emission line equivalent width and the number of hydrogen ionizing photons per unit solar mass

# %% [markdown]
# https://www.aanda.org/articles/aa/pdf/2010/13/aa14183-10.pdf

# %% [markdown]
# В этой статье был произведён анализ звёздообразования в окрестности бара. Для изучения данного вопроса были взяты следующие данные
# >  A combination of UV, Hα, and 24 μm emission is indeed ideal for reconstructing the recent star-formation history of a galaxy by studying the location and properties of individual clusters and those of the gas and dust emission around them.
#
# Хотят получить панхроматический вид бара NGC 2903, который  позволит выявить связь между звездообразоваем и динамикой галактики.
# > a panchromatic view revealing the history of star-formation in bars can provide a unique insight into the links between star-formation and the galaxy dynamics, which may also help us to understand how bars form and evolve
#
# В основу этой работы положен анлиз корреляций между местоположением и возрастом молодых звёздных скоплений, и морфологии бара.

# %% [markdown]
# Есть таблица с следующими данными: светимость Hα(not corrected for internal dust extinction), Hα equivalent width (a measure of the strength of the Hα emission with respect to the continuum emission of the stellar ionizing cluster), 24 μm emission, 24 attenuation,SFR по зависимости от расстояния от центра галактики и позиционного угла.

# %% [markdown]
# https://arxiv.org/pdf/1111.3411.pdf

# %% [markdown]
# С целью изучения звездообразования, с этой статье был произведён анализ мультидлинноволновых изображений. Есть изображения галактики в оптическом и ИК диапозонах.

# %%
Image('./images/optical_IR_images.png')

# %% [markdown]
# > In the images, Hα, 8 μm(dust), and 24 μm bands all can trace the star formation activities. The starforming clumps in 8 μm(dust) and 24 μm images have similar distribution with those in Hα image. Especially in the 24 μm image, the clumps are more pronounced.

# %% [markdown]
# Была получена двумерная модель распределения яркости (исп. техника GALFIT https://iopscience.iop.org/article/10.1086/340952/pdf)
# Так же в этой статье представлены профили поверхностной яркости для диска, балджа и бара, описывыемые экспоненциальными функциями, Серсека и Серсека с n<1 соответственно

# %% [markdown]
# Для изучения свойств звездообразования визуально были отобраны 30 областей ,для которых впослествии были выявлены H$\alpha$ и ИК узкополосные потоки (narrowband fluxes). Для этих областей были получены следующие величины SFR и звёздная масса (Kennicutt et al. (2009)(their Eq.[11] and Table [4]) и Zhu et al.(2010) соотв.)
# На основе этих данных получилась зависимость поверхностной плотности SFR от поверхностной плотности звёздной массы.

# %%
Image('./images/SFR_stellar_mass.png')

# %% [markdown]
# > We found that nearly all disk clumps in both galaxies can grow up in the present SFR in 1–3 Gyr. The clumps in the bulge and the bar of NGC 2903 have a timescale of ∼ 3 Gyr, a little longer than their associated disk.

# %% [markdown]
# #### BAR-DRIVEN SECULAR EVOLUTION

# %% [markdown]
# To measure the ability of driving gas inflow, the parameters of bars have been investigated by many researchers, both physical and dynamical (e.g., Laurikainen et al., 2004; Gadotti et al., 2007; Marinova & Jogee, 2007).
# - Laurikainen, E., Salo, H., & Buta, R., 2004, ApJ, 607, 103
# - Laurikainen, E., Salo, H., Buta, R., & Knapen, J. H. 2007, MNRAS, 381, 401
# - Marinova, I., & Jogee, S. 2007, ApJ, 659, 1176

# %% [markdown]
# > To better understand the evolutionary sequence of bar-driven secular evolution, several scenarios have been proposed (e.g., Martin & Friedli, 1997; Verley et al., 2007). Jogee et al. (2005) analyzed the potential evolutionary connections between the barred starbursts and non-starbursts, and projected a figure of the dynamical evolution driven by stellar bars. In this evolutionary figure, the evolutionary sequence of a strongly barred galaxy was divided into three stages:
# - type I non-starburst is the early stages of bar-driven inflow, with gas still inflowing along the bar and not forming stars efficiently.
# - type II non-starburst, and circumnuclear starburst. In this type, most of the gas has piled up in the circumnuclear region, and then there is a circumnuclear starburst when most of the gas exceeds a critical density.
# - type III non-starburst is in the poststarburst phase, where the gas has been consumed by a circumnuclear starburst, and no molecular gas is within the bar region.
#
# > NGC 2903 is likely in the late stage of the type II non-starburst, where sufficient gas has accumulated to drive a starburst in the central region, although some gas is still in the bar. Under this scenario, more intense star formation activity may take place in the circumnuclear region of NGC 2903 later, along with the star formation activities disappearing in the galactic bar.

# %% [markdown]
# https://arxiv.org/pdf/1101.3224.pdf

# %% [markdown]
# В этой статье, решение уравнения Эйнштейна ОТО сранивалось с известными данными,по которым строится кривая вращения. Исходя из полученных ними результатов они сделали вывод, что ОТО может описать наблюдаемые кривые вращения без учёта тёмной материи.

# %% [markdown]
# https://arxiv.org/pdf/1607.08023.pdf

# %% [markdown]
# В этой работе изучается отношение SFE (star formation efficiencies) и плотности молекулярного газа, используя CO(J=2-1) карты (CO Multi-line Imaging of Nearby Galaxies (COMING) project).

# %%
import matplotlib.pyplot as plt
import os
from astropy.io import fits
import numpy as np
from matplotlib import cm

def fits_file_hist(FileName,a,b):              # FileName- name of fitsfile
    data=fits.getdata(FileName)          # a, b- width and height of picture     
    data=np.nan_to_num(data)               
    width, height=data.shape[2:]        
    X,Y=np.meshgrid(np.arange(0,width,1),np.arange(0,height,1))
    data = np.array(data).reshape((width,height))
    Z=data
    fig=plt.figure(figsize=[a,b])     
    picture=plt.pcolormesh(X,Y,Z)
    plt.colorbar()
    
    FileName.replace('fits','png')
    FileName.replace('data','images')
    way=FileName
    
    plt.savefig(way,format='png')
    plt.show()
    
def fits_file(FileName,a,b):
    data=fits.getdata(FileName)
    fig=plt.figure(figsize=[a,b])
    
    #FileName.replace('fits','png')
    #FileName.replace('data','images')
    #way=FileName
    
    plt.imshow(np.squeeze(data))
    #plt.savefig(way,format='png')
    plt.show()

# %% [markdown]
# ## Данные

# %%
IFrame('./images/intensity_CO.pdf',width=600, height=600)
# Out:
#         <iframe
#             width="600"
#             height="600"
#             src="./images/intensity_CO.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
#  ##### Left: integrated intensity CO J = 2 → 1 intensity along each line of sight. Right: peak CO J = 2 → 1 intensity along each line of sight

# %% [markdown]
# #### Данные из VENGA

# %% [markdown]
# https://users.obs.carnegiescience.edu/~gblancm/venga/dr1/NGC2903/
#
# https://users.obs.carnegiescience.edu/~gblancm/venga/vengacubes/NGC2903/

# %% [markdown]
# Разберёмся с файлом NGC2903_cube.fits

# %%
#from astropy.io import fits
#filename='./data/NGC2903_cube.fits'
#images=fits.open(filename)
#N=len(images)
#for i in range(N):
#    fits.PrimaryHDU(data=images[i].data).writeto('./data/NGC2903_cube/'+str(i)+'.fits')

# %% [markdown]
# таким образом получили 3009 фитсов

# %% [markdown]
# Посмотрим, что из себя представляет файл NGC2903.fits

# %%
from astropy.io import fits
filename='./data/NGC2903.fits'
images=fits.open(filename)
N=len(images)
for i in range(N):
    fits.PrimaryHDU(data=images[i].data).writeto('./data/NGC2903/'+str(i)+'.fits')

# %%
#from astropy.io import fits
#filename='./data/NGC2903_cube_log.fits'
#images=fits.open(filename)
#len(images)
# Out:
# WARNING: non-ASCII characters are present in the FITS file header and have been replaced by "?" characters [astropy.io.fits.util]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-a45615dd6459> in <module>
#       1 from astropy.io import fits
#       2 filename='./data/NGC2903_cube_log.fits'
# ----> 3 images=fits.open(filename)
#       4 len(images)
#
# ~/.local/lib/python3.5/site-packages/astropy/io/fits/hdu/hdulist.py in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, **kwargs)
#     149
#     150     return HDUList.fromfile(name, mode, memmap, save_backup, cache,
# --> 151                             lazy_load_hdus, **kwargs)
#     152
#     153
#
# ~/.local/lib/python3.5/site-packages/astropy/io/fits/hdu/hdulist.py in fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, **kwargs)
# ...

# %%
#from astropy.io import fits
#filename='./data/NGC2903_log.fits'
#images=fits.open(filename)
#len(images)
# Out:
# 2

# %% [markdown]
# Посмотрим, какие изображения находятся в NGC2903.fits

# %%
fits_file('./data/NGC2903/1.fits',5,12)

# %%
fits_file('./data/NGC2903/0.fits',5,12)

# %%
fits_file('./data/NGC2903/4.fits',5,12)

# %%
fits_file('./data/NGC2903/5.fits',5,12)

# %% [markdown]
# на остальных трёх изображена просто горизонтальная линия
