# %% [markdown]
# # Результаты

# %%
from IPython.display import Image
from wand.image import Image as WImage
import os
from PIL import Image as Im
# %pylab
# %matplotlib inline
# %run ./load_notebook.py
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Во-первых, была построена карта параметра Тумре (параметра гравитационной неустойчивости)

# %%
Image('./images/Toomre.png')

# %% [markdown]
# Было преведено исследование в области наилучшего соответствия для $H_{\alpha}$ & $Q_{eff}$. Были посчитаны такие величины, как точность, полнота и F-мера при предельном значении $Q_{eff}^{lim}=3$ (при $Q_{eff}^{lim}>3$ область устойчива). На левом рисунке представлены графики для $F(H_{\alpha}^{lim})$ для полной, обрезанной, с приоритетом для полноты карт.

# %%
Image('./images/statistics2.png')

# %% [markdown]
# Таким образом наилучшее соответствие при $Q_{eff}^{lim}=3$ и $\lg{H_{\alpha}^{lim}} = - 14.15 $

# %% [markdown]
# То же самое исследование было проведено и для galactic shear, только в этом случае мы варьировали параметр $\alpha_A$

# %%
Image('./images/statistics1.png')

# %% [markdown]
# #### Нарисуем параметры гравитационной неустойчивости: параметр Тумре $Q_{eff} (Q_{lim} = 3)$ и galaxy shear $(\alpha_A = 3.3)$ со статистически посчитанными для них $\Sigma_{SFR}^{lim}$ равными  0.045 и 0.032 соответственно

# %%
Image('./images/Q_min_and_galactic_shear1.png')

# %%
Image('./images/Q_min_and_galactic_shear2.png')

# %%
Image('./images/Q_min_and_max.png')

# %% [markdown]
# Для $Q_{eff}^{lim} = 3$ и $\Sigma_{SFR}^{lim} = 0.045$: $F(cut) = 0.44$, $recall(cut) = 0.4$, $presicion(cut) = 0.47$
#
# Для $\alpha_A = 3.3$ и $\Sigma_{SFR}^{lim} = 0.032$: $F(cut) = 0.62$, $recall(cut) = 0.62$, $presicion(cut) = 0.61$

# %% [markdown]
# Далее были проведено исследование на чувствительность параметра неустойчивости к ошибкам (т.е. мы поочерёдно варьировали входные данные и смотрели, как будет меняться результат). Таким образом получили следующий график

# %%
Image('./images/vary.png')

# %%
fig, axes = plt.subplots(3, 2, figsize=[45, 33])
axes[0][0].imshow(Im.open('./images/Sigma_H2_vary.png'))
axes[0][0].set_xticks([])
axes[0][0].set_yticks([])
axes[0][1].imshow(Im.open('./images/Sigma_HI_vary.png'))
axes[0][1].set_xticks([])
axes[0][1].set_yticks([])
axes[1][0].imshow(Im.open('./images/sigma_HI_vary.png'))
axes[1][0].set_xticks([])
axes[1][0].set_yticks([])
axes[1][1].imshow(Im.open('./images//Sigma_s_vary.png'))
axes[1][1].set_xticks([])
axes[1][1].set_yticks([])
axes[2][0].imshow(Im.open('./images/sigma_s_vary.png'))
axes[2][0].set_xticks([])
axes[2][0].set_yticks([])
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Построили карту для параметра гравитац. неустойчивасти cold phase и нашли для него статистику

# %%
Image('./images/cold_phase.png')

# %%
Image('./images/cold_phase_stat.png')

# %% [markdown]
# Можно заметить, что ни параметр Тумре, ни galactic shear не смогли хорошо описать звездообразование в нижней части. Думаю, будет полезно понять почему...

# %% [markdown]
# Были получены карты относительных ошибок данных дисперсии скоростей звёзд. Как раз-таки неточностью этих данных можно объяснить появление "ложных" устойчивых областей с нижнем квадрате.

# %%
Image('./images/relative_error.png')

# %%
Image('./images/instabilities_with_error.png')

# %% [markdown]
# ### Наиболее честный подход в определении $\Sigma_{H2}$

# %% [markdown]
# Из [статьи](https://arxiv.org/pdf/1212.1208.pdf) была найдена карта переходного параметра между $I_{CO}$ и $\Sigma_{H2}$. И я попробовала её интерпретировать для своих данных.

# %%
Image('./images/alpha_CO.png')

# %% [markdown]
# И для новых значений плотности молекулярного газа была найдена карта двухжидкостной неустойчивости

# %%
Image('./images/Toomre_new_min.png')

# %%
Image('./images/Toomre_new_max.png')

# %% [markdown]
# Для определения неутойчивости методом shear, мы уже не можем использовать такую карту (картинка получится изрезанной на квадратики). Для него мы эту карту пеереходного параметра можем интерпретировать по-другому: мы оценим его значения в центре, на спиральных рукавах и на внешнем диске. И получим следующие изображения.

# %%
Image('./images/Sigma_H2_new.png')

# %%
Image('./images/shear_new.png')

# %% [markdown]
# ### Определяющая компонента

# %% [markdown]
# Сначала я сравнила газовую и звездную компоненту параметра двухжидкостной неустойчивости

# %%
Image('./images/gas_and_stars.png')

# %% [markdown]
# Затем я посчитала параметр грав. неустойчивости методом Romeo и нарисовала карты для определяющей компоненты. Определяющей компонентой при mark = 1 является звезда, при 2 атомарный газ HI, при 3 молекулярный H2.(Черные области - области с отрицательным значением плотности молекулярного газа)

# %%
Image('./images/Romeo.png')

# %% [markdown]
# ### Теперь в качестве порога для звездообразования возьмём критерий: область нeустойчива при $\Sigma_{HI}>5
# M_{\odot}/kpc^2 $

# %% [markdown]
# Можем поварьировать пороговое значение и найти наилучшее соответствие

# %%
Image('./images/stat.png')

# %%
Image('./images/stat1.png')

# %% [markdown]
# $F = 0.51$ при $\Sigma_{HI}^{lim} = 5$ и $SFR^{lim} = 0.042$

# %%
Image('./images/Sigma_HI_and_SFR.png')

# %% [markdown]
# Здесь в качестве порогового значния взята 5 $M_{\odot}/kpc^2 $

# %% [markdown]
# ###  Kennicutt-Schmidt law

# %%
Image('./images/K-Sh_law.png')
