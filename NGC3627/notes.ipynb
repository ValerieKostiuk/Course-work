# %% [markdown]
# ### В этом файле хранятся информация и данные по NGC3627

# %%
from IPython.display import Image
from wand.image import Image as WImage
import os
# %pylab
# %matplotlib inline
# %run ./load_notebook.py
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
import functions

# %%
Image('./images/main.png')

# %% [markdown]
# Откроем все фитсы из VENGA

# %%
functions.fits_file('./data/NGC3627_map_ha_corr.fits',12,20)

# %%
functions.fits_file('./data/NGC3627_map_sigstar.fits',12,20)

# %% [markdown]
# Данные из THINGS

# %%
functions.fits_file('./data/NGC_3627_NA_MOM0_THINGS.FITS',12,12)

# %%
functions.fits_file('./data/NGC_3627_NA_MOM1_THINGS.FITS',12,12)

# %%
functions.fits_file('./data/NGC_3627_NA_MOM2_THINGS.FITS',12,12)

# %%
functions.fits_file('./data/ngc3627_emom0_I_CO_J1-2_lwb2009.fits', 12 , 12)

# %%
functions.fits_file('./data/NGC3627.bima12m.cm.fits', 12, 12)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-9889fe3ed17a> in <module>
# ----> 1 functions.fits_file('./data/NGC3627.bima12m.cm.fits', 12, 12)
#
# ~/Документы/Science_activity/Курсовая/NGC3627/functions.ipynb in fits_file(FileName, a, b)
#
# ~/.local/lib/python3.5/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2697         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2698         resample=resample, url=url, **({"data": data} if data is not
# -> 2699         None else {}), **kwargs)
#    2700     sci(__ret)
#    2701     return __ret
#
# ~/.local/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %% [markdown]
# https://arxiv.org/pdf/1904.12430.pdf

# %% [markdown]
# ##### В этой работе есть значения SFR
# ?!? $$SFR = 5.3 10^{42}\left L(H\alpha)_{obs}+ 0.031\cdot L(24\mu m)\right$$
#  >The surface density of SFR (ΣSFR) is evaluated within the observation beam of 22′′, 22′′, and 16′′ for SA, BE, and NR, respectively. The surface density of molecular gas mass Σgas is calculated from the column density of H2 derived from the C18O data assuming the rotation temperature of 10 K. The contribution of He is involved in Σgas by multiplying a factor of 1.36. Here, the source size of 10′′ is not taken into account for both ΣSFR and Σgas. The SFE is calculated as ΣSFR/Σgas.

# %%
Image('./images/SFR.png')

# %%
WImage(filename='./images/apjsab1d63f1.pdf', resolution=100)
# Out:
# ---------------------------------------------------------------------------
# PolicyError                               Traceback (most recent call last)
# <ipython-input-14-dd295052419f> in <module>
# ----> 1 WImage(filename='./images/apjsab1d63f1.pdf', resolution=100)
#
# /usr/local/lib/python3.5/dist-packages/wand/image.py in __init__(self, image, blob, file, filename, format, width, height, depth, background, resolution, pseudo, colorspace, units)
#    8210                 elif filename is not None:
#    8211                     self.read(filename=filename, resolution=resolution,
# -> 8212                               units=units)
#    8213                 # clear the wand format, otherwise any subsequent call to
#    8214                 # MagickGetImageBlob will silently change the image to this
#
# /usr/local/lib/python3.5/dist-packages/wand/image.py in read(self, file, filename, blob, resolution, units)
#    8684             r = library.MagickReadImage(self.wand, filename)
# ...

# %% [markdown]
# https://arxiv.org/pdf/1808.07483.pdf

# %% [markdown]
# В этой статье представлены карты $CO(J=2-1)$ для моментов 0, 1 и 2 SMA, также SMA + IRAM 30 м карта.

# %%
# paste pdf

# %% [markdown]
# Также в этой работе была построена спроектированная кривая вращения

# %%
#paste pdf
