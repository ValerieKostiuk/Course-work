# %% [markdown]
# ### В этом файле хранятся информация и данные по NGC3627

# %%
from IPython.display import Image
from wand.image import Image as WImage
import os
# %pylab
# %matplotlib inline
# %run ./load_notebook.py
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
import functions
# Out:
# importing Jupyter notebook from functions.ipynb
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
Image('./images/main.png')

# %% [markdown]
# Откроем все фитсы из VENGA

# %%
functions.fits_file('./data/NGC3627_map_ha_corr.fits',12,20)

# %%
functions.fits_file('./data/NGC3627_map_sigstar.fits',12,20)

# %% [markdown]
# Данные из THINGS

# %%
functions.fits_file('./data/NGC_3627_NA_MOM0_THINGS.FITS',12,12)

# %%
functions.fits_file('./data/NGC_3627_NA_MOM1_THINGS.FITS',12,12)

# %%
functions.fits_file('./data/NGC_3627_NA_MOM2_THINGS.FITS',12,12)

# %%
functions.fits_file('./data/ngc3627_emom0_I_CO_J1-2_lwb2009.fits', 12 , 12)

# %%
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt
filename='./data/NGC3627.bima12m.cm.fits'
data=fits.getdata(filename)
data=np.nan_to_num(data)               
fig=plt.figure(figsize=[12,12])     
plt.imshow(np.squeeze(data[0][0]),origin='lower',  cmap='gist_yarg') #data[i][j] j можно менять от 0 до 50
plt.colorbar()
plt.show()

# %%
filename='./data/NGC3627.bima12m.cm.fits'
data=fits.getdata(filename)
print(data.shape[0:])
# Out:
# (1, 51, 409, 351)

# %% [markdown]
# https://arxiv.org/pdf/1904.12430.pdf

# %% [markdown]
# ##### В этой работе есть значения SFR
# ?!?  $$ SFR  = 5.37\times 10^{-42}( L_{H\alpha} + 0.031\times L(24\mu m)), M_{\odot}yr^{-1}$$
#  >The surface density of SFR (ΣSFR) is evaluated within the observation beam of 22′′, 22′′, and 16′′ for SA, BE, and NR, respectively. The surface density of molecular gas mass Σgas is calculated from the column density of H2 derived from the C18O data assuming the rotation temperature of 10 K. The contribution of He is involved in Σgas by multiplying a factor of 1.36. Here, the source size of 10′′ is not taken into account for both ΣSFR and Σgas. The SFE is calculated as ΣSFR/Σgas.

# %%
Image('./images/SFR.png')

# %%
Image(filename='./images/CO_SFR.png')

# %% [markdown]
# Observed positions (red circles) in (a) the 3.6 μm image (Kennicutt et al. 2003), (b) the integrated intensity map of CO(J = 1–0) (Kuno et al. 2007), and (c) the surface density map of the star formation rate (SFR). The contour levels are 5, 15, 25, ..., 105 K km s−1 and 0.03, 0.06, 0.12, ..., 0.96 M⊙ yr−1 kpc−2 for (b) and (c), respectively. The observed positions are (α(J2000), δ(J2000)) = (11h20m12.ˢ2, +12°59′47.″1), (11h20m16.ˢ6, +12°58′44.″6), and (11h20m15.ˢ5, +12°59′29.″6), for NGC 3627 SA, NGC 3627 BE, and NGC 3627 NR, respectively. The sizes of the red circles, which are 29″ and 20″, correspond to the largest observation beam sizes of the IRAM 30 m telescope and the Nobeyama 45 m telescope, respectively. The star formation rate is derived from the Hα and the 24 μm maps, which are observed by SINGS (Kennicutt et al. 2003), using Equation (3) (Calzetti et al. 2007). The angular resolution of Hα is convolved to 5″, which is the same angular resolution of 24 μm data, before the deriving SFR.

# %% [markdown]
# https://arxiv.org/pdf/1808.07483.pdf

# %% [markdown]
# В этой статье представлены карты $CO(J=2-1)$ для моментов 0, 1 и 2 SMA, также SMA + IRAM 30 м карта.

# %%
Image(filename='./images/SMA_moments.png')

# %% [markdown]
# Left: SMA moment-0 map of the CO (J = 2 − 1) emission in NGC 3627 imaged with natural weighting and an outer uv-taper of 6 arcsec. The synthesized beam is shown in the lower left corner with FWHM size of 6.″07 × 5.″22 and position angle of 93.°29. Middle: SMA moment-1 map imaged as in the left panel. A substantial velocity gradient is seen in the central bar as well as between the north and south ends of the bar. Right: SMA moment-2 map imaged as in the left panel. The highest velocity dispersion is found in the central bar with the next largest dispersion being seen in the southern end of the galactic bar.

# %% [markdown]
# Также в этой работе была построена спроектированная кривая вращения

# %%
Image(filename='./images/SMA_IRAF.png')

# %% [markdown]
# SMA+IRAM 30 m combined map of the CO(J = 2 − 1) emission in NGC 3627. The synthesized beam is shown in the lower left corner with FWHM size of 5.″39 × 4.″87 and position angle of 85.°57.

# %%
Image(filename='./images/velocity_curve.png')

# %% [markdown]
# Top: deprojected rotation curves for NGC 3627, derived with kinemetry. Bottom: dynamical mass estimates for each galactocentric radius. In some cases, the error bars are smaller than the marker size. For both panels, rotation curves and mass estimates are derived with best-fitting ellipse inclination allowed to vary (solid line) and with inclination fixed to that of NGC 3627 (dashed line).

# %% [markdown]
# Вроде PA = 178

# %% [markdown]
# https://arxiv.org/pdf/1312.0604.pdf

# %%
Image(filename='./images/velocity_2D1.png')

# %%
Image(filename='./images/velocity_2D2.png')

# %%
Image(filename='./images/velocity_2D3.png')

# %%
Image(filename='./images/velocity_2D4.png')

# %% [markdown]
# 2D maps of the H2 emission-line gas (upper panels) and stellar (lower panels) kinematics of NGC 3627 derived from the LR SINFONI data. Regions where no reliable parameters were obtained are shown in grey. The spatial orientation, indicated in the upper-left panel, is the same for all the panels. The dashed line in the H2 velocity map corresponds to the PA of the major axis of the galaxy and the dotted line to the orientation of
# the stellar bar. The contours on the upper-panels show the H2 2.12 µm flux distribution.

# %%
Image(filename='./images/vel_curve.png')

# %% [markdown]
# NGC 3627 –Upper panel: mean values of the velocity measured along the major axis of the galaxy (175◦) in apertures of 0.25×0.25 arcsec;negative radii are north from the nucleus. Lower panel: mean velocity dispersion measured in annular apertures. In both panels blue filled and green open circles correspond to the values measured for the H2 gas in the HR and LR data, respectively. Red filled and orange open squares correspond to the stellar values measured in the HR and LR data, respectively. The error bars indicate the 3σ error in the mean.
